# %%
import igraph as ig
import numpy as np
import pandas as pd
from IPython.core.display import display, SVG
import matplotlib.pyplot as plt
import umap

# %%
## jupyter nbconvert Jupyter\ Slides.ipynb --to slides --post serve
## To install this package with conda run one of the following:
##conda install -c conda-forge python-igraph 
##conda install -c conda-forge/label/gcc7 python-igraph 
##conda install -c conda-forge/label/cf201901 python-igraph

# %%
def readGraph(fn, directed=False):
    g = ig.Graph.Read_Ncol(fn+'.edgelist',directed=directed)
    c = np.loadtxt(fn+'.community',dtype='uint8')
    node_base = min([int(x['name']) for x in g.vs]) ## graphs have 1-based or 0-based nodes 
    comm_base = min(c) ## same for communities
    comm = [c[int(x['name'])-node_base]-comm_base for x in g.vs]
    g.vs['community'] = comm
    g.vs['shape'] = 'circle'
    pal = ig.RainbowPalette(n=max(comm)+1)
    g.vs['color'] = [pal.get(int(i)) for i in comm]
    g.vs['size'] = 10
    g.es['width'] = 1
    return g

# %% [markdown]
# ## LFR15
#
# A synthetic graph with 100 nodes, 7 communities and 15% edges between communities.

# %%
## Load the graph
g = readGraph('Data/LFR15/lfr15')
g.vs['color'] = 'blue'

## pick a layout function
ly = g.layout("kk")  ## kamada-kawai; usually nice
#ly = g.layout("mds") ## multi dimensional scaling
#ly = g.layout("fr")   ## Fruchterman-Reingold
#ly = g.layout("circle")
#ly = g.layout("random")

## Plot
ig.plot(g, layout=ly, bbox=(0,0,400,300))

# %%
## Ground-truth communities are indicated with colours
g = readGraph('Data/LFR15/lfr15')
ig.plot(g, layout=ly, bbox=(0,0,400,300))

# %%
## Illustration: sampling, distances, embedding
fig, ax = plt.subplots(figsize=(8,6))
E = pd.read_csv('Data/LFR15/lfr15-embedding--verse-32-0',sep=' ',skiprows=1,
                header=None)
cl = [g.vs.find(str(x))['color'] for x in E.iloc[:,0]]
Y = umap.UMAP().fit_transform(E.iloc[:,1:])
ax.scatter(Y[:,0],Y[:,1],c=cl,marker="o", picker=True);

# %%
E.head()
# Out:
#    0         1         2         3         4         5         6         7   \
# 0   1 -0.177781  0.556232 -0.328218  0.061373 -0.277478  0.071546 -0.023142
# 1   2  0.281935  0.381806  0.010947 -0.666604 -0.203769 -0.015489  0.103876
# 2   3  0.157529  0.083342 -0.283064  0.083647  0.060081  0.319569  0.115887
# 3   4 -0.251360 -0.717067  0.729433 -0.189615  0.480346 -0.033287 -0.161265
# 4   5 -0.320593  0.127733 -0.703398  0.815125  0.554101 -0.274312 -0.376964
#
#          8         9   ...        23        24        25        26        27  \
# 0  0.514925 -0.375777  ...  0.412158  0.665696 -0.460851 -0.091228 -0.042240
# 1  0.902000  0.846604  ... -0.374630  0.417709 -0.005734  0.127821  0.589378
# 2  0.673641 -0.503788  ... -0.250288 -0.338453 -0.538667  0.844794 -0.493193
# 3  0.251332 -0.256467  ... -0.764752 -0.048785  0.011316  0.330146 -0.321047
# 4  0.160907 -0.392910  ...  0.159178  0.837851 -0.343665 -0.043226  0.488604
#
#          28        29        30        31        32
# 0  0.110758  0.369003  0.041830 -0.021632  0.408705
# 1 -0.094860  0.428575  0.196534  0.486142  0.621216
# 2 -0.274693 -0.371217 -0.442875 -0.106360  0.332185
# 3 -0.271029  0.500165 -0.520050 -0.379815  0.251432
# 4 -0.199251  0.582114 -0.045102  0.030565 -0.175073
#
# [5 rows x 33 columns]

# %%
s = np.random.choice(100,30,replace=False)
sg = g.subgraph(s)
ig.plot(sg, bbox=(0,0,400,300))

# %%
print('Diameters: ',g.diameter(),sg.diameter())
print('Avg degrees: ',np.mean(g.degree()),np.mean(sg.degree()))
print('Avg distances: ',np.mean(g.shortest_paths_dijkstra()),np.mean(sg.shortest_paths_dijkstra()))
# Out:
# Diameters:  6 7
# Avg degrees:  7.28 2.7333333333333334
# Avg distances:  2.8712 inf

# %%
from scipy.spatial.distance import pdist
print('Mean and stdv of distance in vector space:',np.mean(pdist(E.iloc[:, 1:])),np.std(pdist(E.iloc[:, 1:])))
print('Mean and stdv of distance in sampled vector space:',np.mean(pdist(E.iloc[s, 1:])),np.std(pdist(E.iloc[s, 1:])))
# Out:
# Mean and stdv of distance in vector space: 2.9238643087966354 0.44175036338689416
# Mean and stdv of distance in sampled vector space: 2.8985411015778455 0.4388608739023971

# %%
fig, ax = plt.subplots(figsize=(8,6))
cls = [cl[i] for i in s]
ax.scatter(Y[s,0],Y[s,1],c=cls,marker="o", picker=True);

# %% [markdown]
# ## LFR35
#
# A synthetic graph with 100 nodes, 9 communities and 35% edges between communities.

# %%
g = readGraph('Data/LFR35/lfr35')
ly = g.layout("kk")
ig.plot(g, layout=ly, bbox=(0,0,400,300))

# %% [markdown]
# ## LFR55
#
# A synthetic graph with 100 nodes, 9 communities and 55% edges between communities.
#
# This is very noisy.

# %%
g = readGraph('Data/LFR55/lfr55')
ly = g.layout("kk")
ig.plot(g, layout=ly, bbox=(0,0,400,300))

# %%
## College Football Graph
g = readGraph('Data/Football/football')

## Show 'Independent' and 'Sun Belt' as triangles
## 5 Independent play in other conferences (green)
## 7 Sun Belt are broken in 2 (pink)
## 3 other teams play in other conference
g.vs['shape'] = 'circle'
for v in g.vs:
    if v['community'] in [5,10]:
        v['shape']='triangle'
    if v['name'] in ['28','58','110']:
        v['shape']='square'

# %%
ly = g.layout("kk")
ig.plot(g, layout=ly, bbox=(0,0,500,300), vertex_size=8, edge_color='lightgray')

# %%
g = readGraph('Data/Karate/karate')
ly = g.layout("kk")
ig.plot(g, layout=ly, bbox=(0,0,400,300))

# %%
## degree distribution
n, bins, patches = plt.hist(x=g.degree(), bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Degree distribution');

# %%
## coreness distribution
n, bins, patches = plt.hist(x=g.coreness(), bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Coreness distribution');

# %%
## 3-core 
g.vs['core']=g.coreness()
v = [x for x in g.vs if x['core']>2]
sg = g.subgraph(v)
ig.plot(sg, bbox=(0,0,400,300))

# %%
print('diameters:',g.diameter(),sg.diameter()) ## longest shortest path
print('edge connectivity:',g.adhesion(),sg.adhesion()) ## min n_edges to cut graph 
print('average path length:',g.average_path_length(),sg.average_path_length())
# Out:
# diameters: 5 4
# edge connectivity: 1 3
# average path length: 2.409982174688057 2.064935064935065

# %% [markdown]
# ## Centrality

# %%
def setSize(x, lo=8, hi=20):
    s = [np.round(lo+(hi-lo)*(i-min(x))/max(x)) for i in x]
    return s

# %%
## degree
g.vs['size'] = setSize(g.degree())
ig.plot(g, layout=ly, bbox=(0,0,400,300), vertex_label_size=0 )

# %%
## betweenness
g.vs['size'] = setSize(g.betweenness(directed=False))
ig.plot(g, layout=ly, bbox=(0,0,400,300), vertex_label_size=0 )

# %%
# pagerank()
g.vs['size'] = setSize(g.pagerank(directed=False))
ig.plot(g, layout=ly, bbox=(0,0,400,300), vertex_label_size=7 )

# %%
def efficiency(g):
    n = g.vcount()
    s = 0
    for i in range(n-1):
        v = g.get_shortest_paths(i)
        s += np.sum([1/len(x) for x in v[i+1:] if len(x)>0])
    return s/(n*(n-1))

def deltaCentrality(g):
    n = g.vcount()
    dc = []
    eff = efficiency(g)
    for i in range(n):
        G = g.copy()
        el = g.incident(i)
        G.delete_edges(el)
        dc.append((eff-efficiency(G))/eff)
    return dc

# %%
# delta (warning due to some node removal disconnecting the graph)
g.vs['size'] = setSize(deltaCentrality(g))
ig.plot(g, layout=ly, bbox=(0,0,400,300), vertex_label_size=0 )
# Out:
# /opt/software/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: Couldn't reach some vertices at structural_properties.c:740
#   """

# %%
x = g.evcent() ## eigenvector centrality
g.vs['size'] = setSize(x)
ig.plot(g, layout=ly, bbox=(0,0,400,300), vertex_label_size=0 )

# %%
x = g.authority_score() ## hub/authority scores (same for undirected graphs)
g.vs['size'] = setSize(x)
ig.plot(g, layout=ly, bbox=(0,0,400,300), vertex_label_size=0 )

# %%
D = pd.DataFrame({'label':g.vs['name'],'eigencentrality':g.evcent(), 'degree':g.degree(),\
                 'betweenness':g.betweenness(),'closeness':g.closeness(), 'delta':deltaCentrality(g),\
                 'pagerank':g.pagerank(), 'authority':g.authority_score()})
# Out:
# /opt/software/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: Couldn't reach some vertices at structural_properties.c:740
#   """

# %%
D.sort_values(by='degree', ascending=False)
# Out:
#    label  eigencentrality  degree  betweenness  closeness     delta  pagerank  \
# 23    34         1.000000      17   161.051587   0.550000  0.104730  0.102417
# 0      1         0.979777      16   231.071429   0.568966  0.328729  0.097894
# 19    33         0.820526      12    77.357143   0.515625  0.073301  0.072918
# 15     3         0.866265      10    76.017460   0.559322  0.083545  0.057805
# 16     2         0.725962       9    32.478571   0.485294  0.070106  0.053668
# 14     4         0.586753       6     6.454762   0.464789  0.062494  0.036185
# 1     32         0.522795       6    73.009524   0.540984  0.077195  0.037497
# 29    24         0.407773       5     9.300000   0.392857  0.058359  0.031829
# 5     14         0.624656       5    24.215873   0.515625  0.066065  0.029842
# 21    28         0.365291       4    11.792063   0.458333  0.061742  0.025867
# 10     8         0.474454       4     0.000000   0.440000  0.059863  0.024721
# 11     7         0.222556       4    15.833333   0.383721  0.056480  0.029238
# 12     6         0.222556       4    15.833333   0.383721  0.056480  0.029238
# 30    30         0.365503       4     1.542857   0.383721  0.056480  0.026559
# 9      9         0.550728       4    25.362698   0.507692  0.064374  0.024812
# 20    29         0.358843       3     0.947619   0.452055  0.060333  0.019758
# 31    26         0.163498       3     2.027778   0.375000  0.053284  0.021145
# 32    25         0.157951       3     1.166667   0.375000  0.053284  0.021212
# 17    31         0.382489       3     7.276190   0.452055  0.060333  0.019766
# 13     5         0.212514       3     0.333333   0.379310  0.055070  0.022082
# 8     11         0.212514       3     0.333333   0.379310  0.055070  0.022082
# 3     20         0.406409       3    17.146825   0.500000  0.063434  0.019802
# 18    10         0.280318       2     0.447619   0.434211  0.058453  0.014446
# 22    17         0.066857       2     0.000000   0.284483  0.044733  0.016838
# 24    15         0.273448       2     0.000000   0.370787  0.054130  0.014698
# 25    16         0.273448       2     0.000000   0.370787  0.054130  0.014698
# 26    19         0.273448       2     0.000000   0.370787  0.054130  0.014698
# 27    21         0.273448       2     0.000000   0.370787  0.054130  0.014698
# 28    23         0.273448       2     0.000000   0.370787  0.054130  0.014698
# 6     13         0.235297       2     0.000000   0.370787  0.053660  0.014739
# 4     18         0.256207       2     0.000000   0.375000  0.054130  0.014681
# 2     22         0.256207       2     0.000000   0.375000  0.054130  0.014681
# 33    27         0.205102       2     0.000000   0.362637  0.053378  0.015176
# 7     12         0.147165       1     0.000000   0.366667  0.052721  0.009612
#
#     authority
# 23   1.000000
# 0    0.979777
# 19   0.820526
# 15   0.866265
# 16   0.725962
# 14   0.586753
# 1    0.522795
# 29   0.407773
# 5    0.624656
# 21   0.365291
# 10   0.474454
# 11   0.222556
# 12   0.222556
# 30   0.365503
# 9    0.550728
# 20   0.358843
# 31   0.163498
# 32   0.157951
# 17   0.382489
# 13   0.212514
# 8    0.212514
# 3    0.406409
# 18   0.280318
# 22   0.066857
# 24   0.273448
# 25   0.273448
# 26   0.273448
# 27   0.273448
# 28   0.273448
# 6    0.235297
# 4    0.256207
# 2    0.256207
# 33   0.205102
# 7    0.147165

# %%
D.corr('kendall')
# Out:
#                  eigencentrality    degree  betweenness  closeness     delta  \
# eigencentrality         1.000000  0.628983     0.550022   0.676608  0.781209
# degree                  0.628983  1.000000     0.797356   0.766135  0.722775
# betweenness             0.550022  0.797356     1.000000   0.767896  0.721719
# closeness               0.676608  0.766135     0.767896   1.000000  0.908413
# delta                   0.781209  0.722775     0.721719   0.908413  1.000000
# pagerank                0.499106  0.915811     0.699722   0.604542  0.570499
# authority               0.990130  0.635253     0.555505   0.683353  0.788997
#
#                  pagerank  authority
# eigencentrality  0.499106   0.990130
# degree           0.915811   0.635253
# betweenness      0.699722   0.555505
# closeness        0.604542   0.683353
# delta            0.570499   0.788997
# pagerank         1.000000   0.504082
# authority        0.504082   1.000000

# %% [markdown]
# ## Edge betweenness

# %%
g.es['width'] = setSize(g.es.edge_betweenness(),1,7)
g.vs['size'] = 10
ig.plot(g, layout=ly, bbox=(0,0,400,300))

# %%
g.es['width'] = setSize(g.es.edge_betweenness(),1,7)
g.vs['size'] = setSize(g.evcent())
ig.plot(g, layout=ly, bbox=(0,0,400,300))

# %% [markdown]
# ## Assortativity

# %%
## negative mu here: hubs connect to low degree nodes
g.assortativity_degree()
# Out:
# -0.49416650869422823

# %%
## plot degree vs avg neighbour degree
## friendship 'paradox'

deg = [v.degree() for v in g.vs()]
nad = []
for v in g.vs():
    nv = g.neighbors(v)
    nad.append(np.mean([deg[i] for i in nv]))

plt.scatter(deg,nad)
plt.xlim((0,18))
plt.ylim((0,18))
plt.xlabel('node degree', fontsize=14)
plt.ylabel('average neighbour degree', fontsize=14);
plt.plot([0,18],[0,18],'--', c='r');
